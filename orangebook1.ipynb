# %%
import pandas as pd

df = pd.read_csv('products.txt', delimiter='~')
df
# Out:
#                       Ingredient                     DF;Route  \
# 0                     BUDESONIDE         AEROSOL, FOAM;RECTAL
# 1      MINOCYCLINE HYDROCHLORIDE        AEROSOL, FOAM;TOPICAL
# 2                   AZELAIC ACID        AEROSOL, FOAM;TOPICAL
# 3         BETAMETHASONE VALERATE        AEROSOL, FOAM;TOPICAL
# 4         BETAMETHASONE VALERATE        AEROSOL, FOAM;TOPICAL
# ...                          ...                          ...
# 41726           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 41727           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 41728           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 41729           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 41730           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
#
#                    Trade_Name        Applicant       Strength Appl_Type  \
# 0                      UCERIS            SALIX  2MG/ACTUATION         N
# 1                      AMZEEQ          JOURNEY     EQ 4% BASE         N
# ...

# %%
import pandas as pd
df_exc = pd.read_csv('exclusivity.txt', delimiter='~')
df_exc
# Out:
#      Appl_Type  Appl_No  Product_No Exclusivity_Code Exclusivity_Date
# 0            N    11366           2           ODE-96      Aug 7, 2022
# 1            N    20287          11              NPP     May 16, 2022
# 2            N    20287          10              NPP     May 16, 2022
# 3            N    20287           9              NPP     May 16, 2022
# 4            N    20287           8              NPP     May 16, 2022
# ...        ...      ...         ...              ...              ...
# 1996         N   211109           2             GAIN     Aug 27, 2028
# 1997         N   215650           1             GAIN      Dec 7, 2029
# 1998         N   215152           1             GAIN      May 3, 2032
# 1999         N   215153           1             GAIN      May 3, 2032
# 2000         N   215888           1             GAIN     Apr 26, 2032
#
# [2001 rows x 5 columns]
