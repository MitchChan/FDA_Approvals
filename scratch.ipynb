# %%
import pandas as pd

df = pd.read_csv('jan2021.csv')

df.head(5)
# Out:
#   Approval Date                             Drug Name Submission  \
# 0    01/04/2021  BUPROPION HYDROCHLORIDEANDA  #076711   SUPPL-30
# 1    01/04/2021  BUPROPION HYDROCHLORIDEANDA  #076711   SUPPL-31
# 2    01/04/2021  BUPROPION HYDROCHLORIDEANDA  #076711   SUPPL-32
# 3    01/04/2021  BUPROPION HYDROCHLORIDEANDA  #076711   SUPPL-39
# 4    01/04/2021  BUPROPION HYDROCHLORIDEANDA  #076711   SUPPL-40
#
#         Active Ingredients     Company Submission Classification *  \
# 0  BUPROPION HYDROCHLORIDE  IMPAX LABS                    Labeling
# 1  BUPROPION HYDROCHLORIDE  IMPAX LABS                    Labeling
# 2  BUPROPION HYDROCHLORIDE  IMPAX LABS                    Labeling
# 3  BUPROPION HYDROCHLORIDE  IMPAX LABS                    Labeling
# 4  BUPROPION HYDROCHLORIDE  IMPAX LABS                    Labeling
#
#   Submission Status
# 0          Approval
# 1          Approval
# 2          Approval
# 3          Approval
# 4          Approval

# %%
# cd /Users/Mitchell/Documents/Git_FDA_Approvals/data/2021
